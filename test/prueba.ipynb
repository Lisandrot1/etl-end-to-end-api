# %%
import requests
import pandas as pd
from dotenv import dotenv_values

config = dotenv_values('.env')

username = config.get('username')

url = f'http://api.geonames.org/searchJSON?featureClass=P&fcode=PPL&maxRows=1000&username=lisandrot1'

def cities():
    try:
        res = requests.get(url)
        if res.status_code == 200:
            data = res.json()
           
            df = pd.json_normalize(data['geonames'])
            df_names = df['name']
            print(df_names)
            
            
        else:
            print(f'Error falla en la peticion: {res.status_code}: {res.text}')
    except Exception as ex:
        print(f'error :{ex}')
        raise ex
        
        
        
cities()
# Out:
# 0           New York
# 1          Ahmedabad
# 2          Rotterdam
# 3         Les Abymes
# 4            Antwerp
#            ...
# 995          Ballwin
# 996    Atlantic City
# 997      Rocky Mount
# 998       Florissant
# 999        Harlingen
# Name: name, Length: 1000, dtype: object
