# %%
import pandas as pd

df=pd.read_parquet('cities.parquet')

df.head()
# Out:
#    city_id   name_city country_code       lat       lon
# 0  5128581    New York           US  40.71427 -74.00597
# 1  1279233   Ahmedabad           IN  23.02579  72.58727
# 2  2747891   Rotterdam           NL  51.92250   4.47917
# 3  3578959  Les Abymes           GP  16.27300 -61.50507
# 4  2803138     Antwerp           BE  51.22047   4.40026
