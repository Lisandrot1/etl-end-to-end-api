# %%
import pandas as pd

df = pd.read_parquet('weather.parquet')

df.isnull().sum()
# Out:
# date            0
# lat             0
# lon             0
# temp            0
# feels_like      0
# humidity        0
# weather_main    0
# weather_desc    0
# wind_speed      0
# dtype: int64
