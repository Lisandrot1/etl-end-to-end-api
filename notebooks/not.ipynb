# %%
import pandas as pd

df = pd.read_parquet('fact_weather.parquet')

df
# Out:
#        cityId   date_id  temp  feels_like  humidity weather_main  \
# 0     2986306  20260214  2.62       -2.20        80       Clouds
# 1     2985034  20260214  0.74       -1.67        79        Clear
# 2     2986501  20260214  0.93       -1.44        86        Clear
# 3     2986732  20260214  5.86        4.31        78         Rain
# 4     2988621  20260214  0.22        0.22        81        Clear
# ...       ...       ...   ...         ...       ...          ...
# 5391  2850536  20260214  1.13       -2.94        89       Clouds
# 5392  2850995  20260214 -2.90       -5.93        96       Clouds
# 5393  2851079  20260214 -0.86       -5.43        83       Clouds
# 5394  2852101  20260214 -0.07       -2.62        99         Snow
# 5395  2851826  20260214 -2.08       -6.79        93       Clouds
#
#        weather_desc  wind_speed
# 0             nubes        6.17
# 1       cielo claro        2.06
# 2       cielo claro        2.06
# 3     lluvia ligera        2.06
# ...
