# %%
import pandas as pd

df = pd.read_parquet('cities.parquet')
df_c = df[df['cityId']== 2744514]


df_c
# Out:
#       cityId Name_City  countryId  population Country_Code     Country_Name  \
# 501  2744514   Wijchen    2750405       32693           NL  The Netherlands
#
#           lat    lon
# 501  51.80917  5.725
