# %%
import pandas as pd

df = pd.read_parquet('weather2.parquet')

#df['dt'] = pd.to_datetime(df['dt'], unit='s').dt.date

df
# Out:
#               dt      lat      lon   temp  feels_like  humidity weather_main  \
# 0     1770764256  47.2077  -1.5033  11.06       10.65        93       Clouds
# 1     1770764256  43.2676   6.6405  10.39        9.89        92       Clouds
# 2     1770764256  43.4233   6.7735   9.81        9.81       100       Clouds
# 3     1770764256  44.8955  -0.7178  14.13       13.74        82       Clouds
# 4     1770764256  43.7885   4.8317  10.81       10.37        93       Clouds
# ...          ...      ...      ...    ...         ...       ...          ...
# 5995  1770764411  47.8560  12.3462   1.36       -1.76        79       Clouds
# 5996  1770764411  51.2022   7.3603   6.38        3.77        95       Clouds
# 5997  1770764167  49.4445   7.5553   7.22        4.53        99       Clouds
# 5998  1770764411  50.2079   6.4202   7.12        4.69        92         Rain
# 5999  1770764411  51.1111  13.9120   3.09       -1.60        83       Clouds
#
#        weather_desc  wind_speed
# ...
