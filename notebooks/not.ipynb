# %%
import pandas as pd

df = pd.read_parquet('dim_citie.parquet')

df['countryId']
# Out:
# 0       6252001
# 1       2802361
# 2        102358
# 3       1269750
# 4       3579143
#          ...
# 5995    2921044
# 5996    2921044
# 5997    2921044
# 5998    2921044
# 5999    2921044
# Name: countryId, Length: 6000, dtype: int64
