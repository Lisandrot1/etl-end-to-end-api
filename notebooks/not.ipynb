# %%
import pandas as pd

df = pd.read_parquet('cities.parquet')
# Out:
#        cityId            Name_City  countryId  population Country_Code  \
# 0     5128581             New York    6252001     8804190           US
# 1     2803138              Antwerp    2802361      529247           BE
# 2      105343               Jeddah     102358     4697000           SA
# 3     1279233            Ahmedabad    1269750     6357693           IN
# 4     3578959           Les Abymes    3579143       53514           GP
# ...       ...                  ...        ...         ...          ...
# 5995  2850536  Ramstein-Miesenbach    2921044        8078           DE
# 5996  2850995         Radevormwald    2921044       24100           DE
# 5997  2851079             Radeberg    2921044       18747           DE
# 5998  2851826                 Prüm    2921044        5471           DE
# 5999  2852101    Prien am Chiemsee    2921044       10872           DE
#
#        Country_Name       lat       lon
# 0     United States  40.71427 -74.00597
# ...
