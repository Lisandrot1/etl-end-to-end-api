# %%
import pandas as pd

df = pd.read_parquet('cities.parquet')

df
# Out:
#              name
# 0        New York
# 1       Ahmedabad
# 2       Rotterdam
# 3      Les Abymes
# 4         Antwerp
# ...           ...
# 5995     Konnagar
# 5996        Konch
# 5997     Kollegāl
# 5998  Kodungallūr
# 5999   Koch Bihār
#
# [6000 rows x 1 columns]
